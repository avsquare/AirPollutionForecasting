# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
inputData=pd.read_csv("dataset.csv", low_memory=False)

# %%
min_year= pd.to_datetime(inputData["date"]).apply(lambda x: x.year).min()

# %%
inputData["time_index"]=((pd.to_datetime(inputData["date"]).apply(lambda x: x.year) - 
 min_year)*12+ 
 pd.to_datetime(inputData["date"]).apply(lambda x: x.month))

# %%
inputData
# Out:
#        stn_code        sampling_date                        state   location  \
# 0           150   February - M021990               Andhra Pradesh  Hyderabad
# 1           151   February - M021990               Andhra Pradesh  Hyderabad
# 2           152   February - M021990               Andhra Pradesh  Hyderabad
# 3           150      March - M031990               Andhra Pradesh  Hyderabad
# 4           151      March - M031990               Andhra Pradesh  Hyderabad
# 5           152      March - M031990               Andhra Pradesh  Hyderabad
# 6           150      April - M041990               Andhra Pradesh  Hyderabad
# 7           151      April - M041990               Andhra Pradesh  Hyderabad
# 8           152      April - M041990               Andhra Pradesh  Hyderabad
# 9           151        May - M051990               Andhra Pradesh  Hyderabad
# 10          152        May - M051990               Andhra Pradesh  Hyderabad
# ...

# %%
#inputData["sampling_date"]
inputData2=inputData[inputData["location"]=="Delhi"]
inputData2
# Out:
#       stn_code sampling_date  state location                           agency  \
# 65861       60      9/1/1987  Delhi    Delhi  Central Pollution Control Board
# 65862       59      9/2/1987  Delhi    Delhi  Central Pollution Control Board
# 65863       58      9/3/1987  Delhi    Delhi  Central Pollution Control Board
# 65864       57      9/3/1987  Delhi    Delhi  Central Pollution Control Board
# 65865       56      9/2/1987  Delhi    Delhi  Central Pollution Control Board
# 65866       55      9/2/1987  Delhi    Delhi  Central Pollution Control Board
# 65867       60     10/3/1987  Delhi    Delhi  Central Pollution Control Board
# 65868       59     10/4/1987  Delhi    Delhi  Central Pollution Control Board
# 65869       58     10/1/1987  Delhi    Delhi  Central Pollution Control Board
# 65870       57     10/1/1987  Delhi    Delhi  Central Pollution Control Board
# 65871       56     10/3/1987  Delhi    Delhi  Central Pollution Control Board
# ...

# %%
len(pd.to_datetime(inputData["date"]))
# Out:
# 435742

# %%
inputData.shape[0]
# Out:
# 435742

# %%
pd.to_datetime(inputData["date"]).isnull().sum()
# Out:
# 7

# %%
type(pd.to_datetime(inputData["date"].iloc[1]))
# Out:
# pandas.tslib.Timestamp

# %%
inputData2.to_csv("Delhi_Data.csv")

# %%
from matplotlib.pyplot import figure

# %%
figure(figsize=(20,10))

plt.subplot(2,2,1)
plt.scatter(x=inputData2["time_index"],y=inputData2["no2"], color='Red', alpha=0.1)

plt.subplot(2,2,2)
plt.scatter(x=inputData2["time_index"],y=inputData2["so2"], color='Blue', alpha=0.1)

plt.subplot(2,2,3)
plt.scatter(x=inputData2["time_index"],y=inputData2["spm"], color='Green', alpha=0.1)

plt.subplot(2,2,4)
plt.scatter(x=inputData2["time_index"],y=inputData2["rspm"], color='Purple', alpha=0.1)

#plt.scatter(x=inputData2["time_index"],y=inputData2["spm"], color='Purple', alpha=0.1)
plt.show()

# %%
figure(figsize=(30,20))
inputData2.groupby("time_index")["spm"].mean().plot()
#inputData2.groupby("time_index")["no2"].mean().to_csv("DelhiAvergaedSeries.csv")
for i in range(30):
    plt.axvline(x=12*i,color='k', linestyle='--')
plt.show()
